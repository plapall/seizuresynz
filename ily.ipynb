# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Epileptic Seizure Recognition.csv").drop(columns=["Unnamed"])

# %%
one = df[df.y == 1]

# %%
print('else: ', 11500-2300, "\n", "one: ", 2300)
# Out:
# else:  9200
#  one:  2300
